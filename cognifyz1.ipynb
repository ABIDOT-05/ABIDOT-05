# %% [markdown]
# <a href="https://colab.research.google.com/github/ABIDOT-05/ABIDOT-05/blob/main/cognifyz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
df= pd.read_csv('/content/Dataset .csv')
print(df.shape)
df.describe(include='all')
# df.isnull().sum()
df.dropna()
# Out:
# (9551, 21)
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
rx=df.dropna()
y=x.isnull().sum()
print(y)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.duplicated()
df['Cuisines'].value_counts().head(3)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
top_cuisines = df['Cuisines'].value_counts().head(3)
resto= (top_cuisines/9542)*100
print(resto)
# Out:
# Cuisines
# North Indian             9.809264
# North Indian, Chinese    5.355271
# Chinese                  3.709914
# Name: count, dtype: float64

# %%
y=df.groupby('City')['Restaurant Name'].value_counts()
t=y.tail(1)
print(t)
# Out:
# City       Restaurant Name
# ��stanbul  Walter's Coffee Roastery    1
# Name: count, dtype: int64

# %%
max_city = df['City'].value_counts()
print(max_city)
# Out:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
df.groupby('City')['Aggregate rating'].mean()
average_mean= df.groupby('City')['Aggregate rating'].mean()
top_resto = average_mean.sort_values(ascending=False)
print(top_resto.head(1))
# Out:
# City
# Inner City    4.9
# Name: Aggregate rating, dtype: float64

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
plt.hist(df['Price range'])
plt.show()

# %%
PR=df['Price range'].value_counts()
percentages = (PR/9542)*100
print(percentages)
# Out:
# Price range
# 1    46.573045
# 2    32.624188
# 3    14.755816
# 4     6.141270
# Name: count, dtype: float64

# %%
OD=df['Has Online delivery'].value_counts().tail(1)
percentages = (OD/9542)*100
print(percentages)
# Out:
# Has Online delivery
# Yes    25.686439
# Name: count, dtype: float64

# %%
df.groupby('Has Online delivery')['Aggregate rating'].mean()
# Out:
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64
